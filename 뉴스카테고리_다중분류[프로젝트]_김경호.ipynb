# %% [markdown]
# <a href="https://colab.research.google.com/github/smartfarmer1997/first-repository/blob/master/%EB%89%B4%EC%8A%A4%EC%B9%B4%ED%85%8C%EA%B3%A0%EB%A6%AC_%EB%8B%A4%EC%A4%91%EB%B6%84%EB%A5%98%5B%ED%94%84%EB%A1%9C%EC%A0%9D%ED%8A%B8%5D_%EA%B9%80%EA%B2%BD%ED%98%B8.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #오늘 할일
# ### 실험 또 실험 🤯
#
#
# 1. 단어장 개수를 바꾸면서(10000, 5000, Nan) 8개의 ML모델을 사용해보고  accuacry와 f1-score를 비교
# (표로 나타내보세요~) (벡터화는 tf-idf로 통일)
# 2. 팀원끼리 Voca size를 구분해서 돌려보고 결과를 공유하기로 하였음.
#     - 10000개 - 최은서
#     - 5000개 - 김경호
#     - 3000개 - 홍영표
#     - 무한대 - 박기웅
#
#
# ### 📊 단어장 개수별 ML 모델 성능 비교 (Accuracy / F1-score)
#
# | Vocabulary Size | Model                       | Accuracy | F1-Score |
# |------------------|----------------------------|----------|----------|
# | 10000            | ComplementNB               |0.7707|0.7457|
# |                  | LogisticRegression         |0.8085|0.8023|
# |                  | LinearSVC                  |0.7809|0.7771|
# |                  | DecisionTreeClassifier     |0.6202|0.5776|
# |                  | RandomForestClassifier     |0.6741|0.6429|
# |                  | GradientBoostingClassifier |0.7671|0.7637|
# |                  | voting_classifier          |0.7947|0.7907|
# |                  | XGBoost                    |0.7930|0.7856|
# | 5000             | ComplementNB               |0.7707|0.7459|
# |                  | LogisticRegression         |0.8054|0.7993|
# |                  | LinearSVC                  |0.7716|0.7672|
# |                  | DecisionTreeClassifier     |0.6180|0.5730|
# |                  | RandomForestClassifier     |0.7012|0.6770|
# |                  | GradientBoostingClassifier |0.7667|0.7650|
# |                  | voting_classifier          |0.7961|0.7922|
# |                  | XGBoost                    |0.7961|0.7897|
# | 3000             | ComplementNB               |0.7645|0.7370|
# |                  | LogisticRegression         |0.7916|0.7855|
# |                  | LinearSVC                  |0.7578|0.7555|
# |                  | DecisionTreeClassifier     |0.6260|0.5800|
# |                  | RandomForestClassifier     |0.6857|0.6592|
# |                  | GradientBoostingClassifier |0.6857|0.7684|
# |                  | voting_classifier          |0.8032|0.7862|
# |                  | XGBoost                    |0.7885|0.7816|
# | NaN (All words)  | ComplementNB               |0.7649|0.7347|
# |                  | LogisticRegression         |0.8112|0.8055|
# |                  | LinearSVC                  |0.7956|0.7916|
# |                  | DecisionTreeClassifier     |0.6211|0.5769|
# |                  | RandomForestClassifier     |0.6545|0.6226|
# |                  | GradientBoostingClassifier |0.7680|0.7627|
# |                  | voting_classifier          |0.8054|0.8007|
# |                  | XGBoost                    |0.7939|0.7877|
#
# 2. 딥러닝과 머신런닝의 차이 비교하기
# - 벡터화 방법을 바꿔보며(DTM, W2V) 머신러닝 모델1개(성능 잘나온 친구) , 딥러닝 모델 2개(Dense, RNN)를 비교해보세요 평가지표 = accuacry, f1-score
#
# ### 📊 벡터화 방법별 ML/DL 모델 성능 비교 (Accuracy / F1-score)
#
# | Vectorization | Model           | Accuracy | F1-Score |
# |---------------|------------------|----------|----------|
# | Word2Vec      | ML Model (ex. LogisticRegression) |0.8085|0.8023|
# |               | Dense NN         |0.6589|0.6100|
# |               | RNN              |0.7894|0.7830|

# %% [markdown]
# ##

# %% [markdown]
# # 데이터셋 만들기

# %%
# !pip install gensim
# Out:
# Requirement already satisfied: gensim in /usr/local/lib/python3.11/dist-packages (4.3.3)
# Requirement already satisfied: numpy<2.0,>=1.18.5 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.26.4)
# Requirement already satisfied: scipy<1.14.0,>=1.7.0 in /usr/local/lib/python3.11/dist-packages (from gensim) (1.13.1)
# Requirement already satisfied: smart-open>=1.8.1 in /usr/local/lib/python3.11/dist-packages (from gensim) (7.1.0)
# Requirement already satisfied: wrapt in /usr/local/lib/python3.11/dist-packages (from smart-open>=1.8.1->gensim) (1.17.2)

# %%
from tensorflow.keras.datasets import reuters
import tensorflow as tf
import matplotlib.pyplot as plt
import seaborn as sns
import numpy as np
import pandas as pd
from sklearn.metrics import accuracy_score, f1_score

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfTransformer

# %% [markdown]
# # 데이터 준비
# ## index -> text
# ## DTM , TF-idf 학습데이터 준비
# ## W2V 학습데이터 준비

# %%
(x_train, y_train), (x_test, y_test) = reuters.load_data(num_words=5000, test_split=0.2)

# %%
word_index = reuters.get_word_index(path="reuters_word_index.json")

# %%
index_to_word = { index+3 : word for word, index in word_index.items() }
for index, token in enumerate(("<pad>", "<sos>", "<unk>")):
  index_to_word[index]=token

# %%
decoded = []
for i in range(len(x_train)):
    t = ' '.join([index_to_word[index] for index in x_train[i]])
    decoded.append(t)

x_train = decoded
print(len(x_train))
# Out:
# 8982

# %%
decoded_test = []
for i in range(len(x_test)):
    t = ' '.join([index_to_word[index] for index in x_test[i]])
    decoded_test.append(t)

x_test = decoded_test
print(len(x_test))
# Out:
# 2246

# %%
# 벡터화 DTM, TF-idf 방법
dtmvector = CountVectorizer()

tfidf_transformer = TfidfTransformer()

x_train_dtm = dtmvector.fit_transform(x_train)
x_test_dtm= dtmvector.transform(x_test)

x_train_tfidf = tfidf_transformer.fit_transform(x_train_dtm)
x_test_tfidf = tfidf_transformer.transform(x_test_dtm)

# %%
x_train[3]
# Out:
# "<sos> the farmers home administration the u s agriculture department's farm lending arm could lose about seven billion dlrs in outstanding principal on its severely <unk> borrowers or about one fourth of its farm loan portfolio the general accounting office gao said in remarks prepared for delivery to the senate agriculture committee brian <unk> senior associate director of gao also said that a preliminary analysis of proposed changes in <unk> financial <unk> standards indicated as many as one half of <unk> borrowers who received new loans from the agency in 1986 would be <unk> under the proposed system the agency has proposed <unk> <unk> credit using a variety of financial <unk> instead of <unk> <unk> on <unk> ability senate agriculture committee chairman <unk> <unk> d <unk> <unk> the proposed <unk> changes telling <unk> administrator <unk> clark at a hearing that they would mark a dramatic shift in the <unk> purpose away from being <unk> <unk> of last <unk> toward becoming a big city bank but clark <unk> the new regulations saying the agency had a responsibility to <unk> its 70 billion dlr loan portfolio in a <unk> yet <unk> manner <unk> of gao <unk> <unk> arm said the proposed credit <unk> system attempted to ensure that <unk> would make loans only to borrowers who had a reasonable change of <unk> their debt reuter 3"

# %%
# 벡터화 W2V방법
from gensim.models import Word2Vec

# 우선 문장을 토큰화 시킵시다 띄어쓰기 기반으로 해볼게요! -> # 위에서 DTM만들때는 왜 안해줬냐! -> CountVectorizer에서 띄어쓰기 기반 토큰화가 내장되있음
x_train_tokenized = [sentence.split() for sentence in x_train]
x_test_tokenized = [sentence.split() for sentence in x_test]

model = Word2Vec(sentences = x_train_tokenized, vector_size = 256, window = 5, min_count = 5, workers = 4, sg = 0)
print("모델 학습 완료!")
# Out:
# 모델 학습 완료!

# %%
# W2V이 잘되었는지 확인 -> 여차저차 되긴한것같다
model_result = model.wv.most_similar('man')
print(model_result)
# Out:
# [('dan', 0.7888121008872986), ('gordon', 0.7843162417411804), ('disputed', 0.7713534832000732), ('missouri', 0.7707248330116272), ('roberts', 0.7673445343971252), ('rica', 0.7663387060165405), ('pat', 0.7657415270805359), ('cooperative', 0.763624906539917), ('iowa', 0.7597930431365967), ('costa', 0.7597801089286804)]

# %%
# 학습된 Word2Vec 모델
w2v_model = model

# 각 문장을 벡터화 시키는 코드
def vectorize_sentence(sentence, model, max_len):
    vecs = []
    for word in sentence:
        if word in model.wv:
            vecs.append(model.wv[word])
        else:
            vecs.append(np.zeros(model.vector_size))
    # Padding
    if len(vecs) < max_len:
        vecs += [np.zeros(model.vector_size)] * (max_len - len(vecs))
    else:
        vecs = vecs[:max_len]
    return np.array(vecs)


# 최대 문장길이를 잘 잡아주세요
x_train_w2v = np.array([vectorize_sentence(s, w2v_model, max_len=100) for s in x_train_tokenized])
x_test_w2v = np.array([vectorize_sentence(s, w2v_model, max_len=100) for s in x_test_tokenized])

# %%
x_train_w2v.shape
# Out:
# (8982, 100, 256)

# %%
x_test_w2v.shape
# Out:
# (2246, 100, 256)

# %% [markdown]
# # 머신러닝 모델

# %%
from sklearn.naive_bayes import MultinomialNB #다항분포 나이브 베이즈 모델
from sklearn.linear_model import LogisticRegression, SGDClassifier
from sklearn.naive_bayes import ComplementNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.ensemble import VotingClassifier
from sklearn.svm import LinearSVC
from sklearn.metrics import accuracy_score #정확도 계산
from sklearn.metrics import classification_report

# %% [markdown]
# ## ComplementNB

# %%
cb = ComplementNB()
cb.fit(x_train_tfidf, y_train)
# Out:
# ComplementNB()

# %%
# 예측
y_pred = cb.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7707
# ✅ F1-score : 0.7459

# %% [markdown]
# ## LogisticRegression

# %%
lr = LogisticRegression(C=10000, penalty='l2', max_iter=3000)
lr.fit(x_train_tfidf, y_train)
# Out:
# LogisticRegression(C=10000, max_iter=3000)

# %%
# 예측
y_pred = lr.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.8054
# ✅ F1-score : 0.7993

# %% [markdown]
# ## LinearSVC

# %%
lsvc = LinearSVC(C=1000, penalty='l1', max_iter=3000, dual=False)
lsvc.fit(x_train_tfidf, y_train)
# Out:
# /usr/local/lib/python3.11/dist-packages/sklearn/svm/_base.py:1249: ConvergenceWarning: Liblinear failed to converge, increase the number of iterations.
#   warnings.warn(
# LinearSVC(C=1000, dual=False, max_iter=3000, penalty='l1')

# %%
# 예측
y_pred = lsvc.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7716
# ✅ F1-score : 0.7672

# %% [markdown]
# ## DecisionTreeClassifier

# %%
tree = DecisionTreeClassifier(max_depth=10, random_state=0)
tree.fit(x_train_tfidf, y_train)
# Out:
# DecisionTreeClassifier(max_depth=10, random_state=0)

# %%
# 예측
y_pred = tree.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.6180
# ✅ F1-score : 0.5730

# %% [markdown]
# ## RandomForestClassifier

# %%
forest = RandomForestClassifier(n_estimators=5, random_state=0)
forest.fit(x_train_tfidf, y_train)
# Out:
# RandomForestClassifier(n_estimators=5, random_state=0)

# %%
# 예측
y_pred = forest.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7012
# ✅ F1-score : 0.6770

# %% [markdown]
# ## GradientBoostingClassifier

# %%
# 15분 정도 소요될 수 있습니다.
grbt = GradientBoostingClassifier(random_state=0) # verbose=3
grbt.fit(x_train_tfidf, y_train)
# Out:
# GradientBoostingClassifier(random_state=0)

# %%
# 예측
y_pred = grbt.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7667
# ✅ F1-score : 0.7650

# %% [markdown]
# ## voting_classifier

# %%
log_clf = LogisticRegression(penalty='l2', solver='lbfgs', max_iter=1000)
nb_clf = ComplementNB()
gb_clf = GradientBoostingClassifier()

# Voting Classifier 선언
voting_classifier = VotingClassifier(
    estimators=[
        ('lr', log_clf),
        ('nb', nb_clf),
        ('gb', gb_clf)
    ],
    voting='soft'
)
voting_classifier.fit(x_train_tfidf, y_train)
# Out:
# VotingClassifier(estimators=[('lr', LogisticRegression(max_iter=1000)),
#                              ('nb', ComplementNB()),
#                              ('gb', GradientBoostingClassifier())],
#                  voting='soft')

# %%
# 예측
y_pred = voting_classifier.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7961
# ✅ F1-score : 0.7922

# %% [markdown]
# ## XGBoost

# %%
# TF-idf데이터로 XGBoost 모델 학습하기

# 이친구도 시간좀 걸립니다!

from xgboost import XGBClassifier

# XGBoost 모델 학습
xgb_model = XGBClassifier(n_estimators=100, max_depth=5, eval_metric='mlogloss')
xgb_model.fit(x_train_tfidf, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# 예측
y_pred = xgb_model.predict(x_test_tfidf)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7961
# ✅ F1-score : 0.7897

# %% [markdown]
# # 모델 정의 및 실험
# 머신러닝 실험은 저번 코드를 참고해주세요~
#
# 두번째 실험에 대해서만 다루겠습니다

# %%
# 데이터를 단어단위에서 문장단위로 바꿔줘야합니다.. ML은 2차원데이터만 받을수있기때문
# 문장에 대해서 토큰들의 벡터를 평균을 취해줍니다.

# Word2Vec 임베딩 시퀀스: (8982, 100, 256)
x_w2v_seq_train = x_train_w2v
x_w2v_seq_test = x_test_w2v
# 평균 풀링 → (8982, 256)
x_w2v_avg_train = np.mean(x_w2v_seq_train, axis=1)
x_w2v_avg_test = np.mean(x_w2v_seq_test, axis=1)
print(x_w2v_avg_train.shape)  # (8982, 256)
# Out:
# (8982, 256)

# %%
# Word2Vec 데이터로 XGBoost 모델 학습하기
from xgboost import XGBClassifier


# XGBoost 모델 학습
xgb_model = XGBClassifier(n_estimators=100, max_depth=5, eval_metric='mlogloss')
xgb_model.fit(x_w2v_avg_train, y_train)
# Out:
# XGBClassifier(base_score=None, booster=None, callbacks=None,
#               colsample_bylevel=None, colsample_bynode=None,
#               colsample_bytree=None, device=None, early_stopping_rounds=None,
#               enable_categorical=False, eval_metric='mlogloss',
#               feature_types=None, gamma=None, grow_policy=None,
#               importance_type=None, interaction_constraints=None,
#               learning_rate=None, max_bin=None, max_cat_threshold=None,
#               max_cat_to_onehot=None, max_delta_step=None, max_depth=5,
#               max_leaves=None, min_child_weight=None, missing=nan,
#               monotone_constraints=None, multi_strategy=None, n_estimators=100,
#               n_jobs=None, num_parallel_tree=None, objective='multi:softprob', ...)

# %%
# 예측
y_pred = xgb_model.predict(x_w2v_avg_test)

# 평가 지표
acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy : {acc:.4f}")
print(f"✅ F1-score : {f1:.4f}")
# Out:
# ✅ Accuracy : 0.7240
# ✅ F1-score : 0.7080

# %% [markdown]
# # 딥러닝

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Flatten, Dense, Dropout, LSTM, Dense, Dropout


dense_model = Sequential([
    Flatten(input_shape=(100, 256)),  # (seq_len, embedding_dim)
    Dense(512, activation='relu'),
    Dropout(0.3),
    Dense(128, activation='relu'),
    Dropout(0.3),
    Dense(46, activation='softmax')   # 클래스 수에 맞게 조정 46개로 맞춰주세요!
])

dense_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
dense_model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 25600)          │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 512)            │    13,107,712 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 512)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        65,664 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_1 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 46)             │         5,934 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 13,179,310 (50.28 MB)
#  Trainable params: 13,179,310 (50.28 MB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 시간이 좀 걸립니다! 한 20분정도..
dense_model.fit(x_train_w2v, y_train, epochs=50, batch_size=24, validation_split=0.2)
# Out:
# Epoch 1/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9412 - loss: 0.3173 - val_accuracy: 0.6683 - val_loss: 8.6272
# Epoch 2/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 6s 6ms/step - accuracy: 0.9382 - loss: 0.3163 - val_accuracy: 0.6617 - val_loss: 8.1295
# Epoch 3/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9452 - loss: 0.2558 - val_accuracy: 0.6661 - val_loss: 8.1115
# Epoch 4/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9433 - loss: 0.2784 - val_accuracy: 0.6706 - val_loss: 9.2836
# Epoch 5/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9451 - loss: 0.3164 - val_accuracy: 0.6650 - val_loss: 8.3788
# Epoch 6/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9336 - loss: 0.3664 - val_accuracy: 0.6628 - val_loss: 7.7632
# Epoch 7/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9388 - loss: 0.2817 - val_accuracy: 0.6622 - val_loss: 8.8479
# Epoch 8/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9417 - loss: 0.2551 - val_accuracy: 0.6600 - val_loss: 8.3193
# Epoch 9/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9377 - loss: 0.2909 - val_accuracy: 0.6661 - val_loss: 8.0143
# Epoch 10/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9397 - loss: 0.2972 - val_accuracy: 0.6661 - val_loss: 8.8485
# Epoch 11/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9425 - loss: 0.3456 - val_accuracy: 0.6617 - val_loss: 8.1956
# Epoch 12/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9442 - loss: 0.2365 - val_accuracy: 0.6617 - val_loss: 8.2714
# Epoch 13/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9377 - loss: 0.3884 - val_accuracy: 0.6617 - val_loss: 7.8288
# Epoch 14/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9409 - loss: 0.2760 - val_accuracy: 0.6656 - val_loss: 8.2510
# Epoch 15/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9395 - loss: 0.3261 - val_accuracy: 0.6644 - val_loss: 8.0620
# Epoch 16/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9421 - loss: 0.3671 - val_accuracy: 0.6539 - val_loss: 7.7370
# Epoch 17/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9394 - loss: 0.2839 - val_accuracy: 0.6589 - val_loss: 7.8438
# Epoch 18/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9406 - loss: 0.2813 - val_accuracy: 0.6594 - val_loss: 8.4363
# Epoch 19/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9422 - loss: 0.2798 - val_accuracy: 0.6600 - val_loss: 8.7006
# Epoch 20/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9335 - loss: 0.3448 - val_accuracy: 0.6572 - val_loss: 8.7302
# Epoch 21/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9421 - loss: 0.2526 - val_accuracy: 0.6578 - val_loss: 8.6573
# Epoch 22/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9385 - loss: 0.3238 - val_accuracy: 0.6605 - val_loss: 8.9218
# Epoch 23/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9409 - loss: 0.3050 - val_accuracy: 0.6639 - val_loss: 8.8754
# Epoch 24/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9347 - loss: 0.2966 - val_accuracy: 0.6644 - val_loss: 8.8221
# Epoch 25/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9416 - loss: 0.3019 - val_accuracy: 0.6533 - val_loss: 8.7058
# Epoch 26/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9356 - loss: 0.2746 - val_accuracy: 0.6617 - val_loss: 9.1084
# Epoch 27/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9373 - loss: 0.2855 - val_accuracy: 0.6628 - val_loss: 9.2880
# Epoch 28/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9404 - loss: 0.2970 - val_accuracy: 0.6611 - val_loss: 9.2231
# Epoch 29/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9342 - loss: 0.2763 - val_accuracy: 0.6633 - val_loss: 9.1750
# Epoch 30/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9412 - loss: 0.2677 - val_accuracy: 0.6661 - val_loss: 9.6553
# Epoch 31/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9465 - loss: 0.2733 - val_accuracy: 0.6605 - val_loss: 9.3940
# Epoch 32/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9441 - loss: 0.2499 - val_accuracy: 0.6555 - val_loss: 8.9700
# Epoch 33/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9381 - loss: 0.3011 - val_accuracy: 0.6544 - val_loss: 9.0277
# Epoch 34/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9370 - loss: 0.3002 - val_accuracy: 0.6550 - val_loss: 9.0517
# Epoch 35/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9432 - loss: 0.2688 - val_accuracy: 0.6550 - val_loss: 9.0730
# Epoch 36/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9410 - loss: 0.2759 - val_accuracy: 0.6633 - val_loss: 9.5796
# Epoch 37/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9392 - loss: 0.2662 - val_accuracy: 0.6528 - val_loss: 9.5774
# Epoch 38/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9383 - loss: 0.3209 - val_accuracy: 0.6583 - val_loss: 9.3268
# Epoch 39/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9387 - loss: 0.2864 - val_accuracy: 0.6444 - val_loss: 8.8492
# Epoch 40/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9377 - loss: 0.3367 - val_accuracy: 0.6489 - val_loss: 8.7175
# Epoch 41/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9420 - loss: 0.2627 - val_accuracy: 0.6505 - val_loss: 9.1361
# Epoch 42/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9391 - loss: 0.3235 - val_accuracy: 0.6566 - val_loss: 9.9080
# Epoch 43/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9361 - loss: 0.3245 - val_accuracy: 0.6522 - val_loss: 10.5066
# Epoch 44/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 7ms/step - accuracy: 0.9345 - loss: 0.3859 - val_accuracy: 0.6427 - val_loss: 9.1101
# Epoch 45/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9351 - loss: 0.2964 - val_accuracy: 0.6444 - val_loss: 9.8301
# Epoch 46/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9426 - loss: 0.2628 - val_accuracy: 0.6600 - val_loss: 10.3133
# Epoch 47/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 6ms/step - accuracy: 0.9417 - loss: 0.3282 - val_accuracy: 0.6633 - val_loss: 10.5335
# Epoch 48/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 3s 6ms/step - accuracy: 0.9380 - loss: 0.2819 - val_accuracy: 0.6566 - val_loss: 10.1482
# Epoch 49/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9372 - loss: 0.3112 - val_accuracy: 0.6489 - val_loss: 10.3613
# Epoch 50/50
# 300/300 ━━━━━━━━━━━━━━━━━━━━ 2s 7ms/step - accuracy: 0.9415 - loss: 0.3001 - val_accuracy: 0.6622 - val_loss: 11.6918

# %%
y_pred_proba = dense_model.predict(x_test_w2v)
y_pred = np.argmax(y_pred_proba, axis=1)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy: {acc:.4f}")
print(f"✅ F1-score: {f1:.4f}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 3ms/step
# ✅ Accuracy: 0.6589
# ✅ F1-score: 0.6100

# %%
# rnn 시계열 특징 데이터 특화 모델

rnn_model = Sequential([
    LSTM(128, input_shape=(100, 256)),  # (seq_len, embedding_dim)
    Dropout(0.3),
    Dense(64, activation='relu'),
    Dropout(0.3),
    Dense(46, activation='softmax')   # 클래스 수에 맞게 조정 46개로 맞춰주세요~
])

rnn_model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])
rnn_model.summary()
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# Model: "sequential_1"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ lstm (LSTM)                     │ (None, 128)            │       197,120 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_2 (Dropout)             │ (None, 128)            │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_3 (Dense)                 │ (None, 64)             │         8,256 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout_3 (Dropout)             │ (None, 64)             │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_4 (Dense)                 │ (None, 46)             │         2,990 │
# └─────────────────────────────────┴────────────────────────┴───────────────┘
#  Total params: 208,366 (813.93 KB)
#  Trainable params: 208,366 (813.93 KB)
#  Non-trainable params: 0 (0.00 B)

# %%
# 시간이 좀 걸립니다! 한 20분정도
rnn_model.fit(x_train_w2v, y_train, epochs=40, batch_size=8, validation_split=0.2)
# Out:
# Epoch 1/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9174 - loss: 0.2801 - val_accuracy: 0.7730 - val_loss: 1.4865
# Epoch 2/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 9s 8ms/step - accuracy: 0.8997 - loss: 0.3570 - val_accuracy: 0.7641 - val_loss: 1.3850
# Epoch 3/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9118 - loss: 0.3337 - val_accuracy: 0.7663 - val_loss: 1.4312
# Epoch 4/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9012 - loss: 0.3367 - val_accuracy: 0.7718 - val_loss: 1.4232
# Epoch 5/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9245 - loss: 0.2863 - val_accuracy: 0.7746 - val_loss: 1.4718
# Epoch 6/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9251 - loss: 0.2853 - val_accuracy: 0.7718 - val_loss: 1.5441
# Epoch 7/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9220 - loss: 0.2891 - val_accuracy: 0.7785 - val_loss: 1.5275
# Epoch 8/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9190 - loss: 0.3048 - val_accuracy: 0.7735 - val_loss: 1.5728
# Epoch 9/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9258 - loss: 0.2652 - val_accuracy: 0.7769 - val_loss: 1.5225
# Epoch 10/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9126 - loss: 0.3025 - val_accuracy: 0.7691 - val_loss: 1.4999
# Epoch 11/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9145 - loss: 0.2985 - val_accuracy: 0.7724 - val_loss: 1.5641
# Epoch 12/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9244 - loss: 0.2667 - val_accuracy: 0.7819 - val_loss: 1.6114
# Epoch 13/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9252 - loss: 0.2736 - val_accuracy: 0.7763 - val_loss: 1.6075
# Epoch 14/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9220 - loss: 0.2606 - val_accuracy: 0.7585 - val_loss: 1.6458
# Epoch 15/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 10ms/step - accuracy: 0.9236 - loss: 0.2686 - val_accuracy: 0.7713 - val_loss: 1.4983
# Epoch 16/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9194 - loss: 0.2876 - val_accuracy: 0.7702 - val_loss: 1.6156
# Epoch 17/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 7s 8ms/step - accuracy: 0.9223 - loss: 0.2652 - val_accuracy: 0.7702 - val_loss: 1.6029
# Epoch 18/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 9ms/step - accuracy: 0.9280 - loss: 0.2410 - val_accuracy: 0.7718 - val_loss: 1.5888
# Epoch 19/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9189 - loss: 0.2767 - val_accuracy: 0.7741 - val_loss: 1.6621
# Epoch 20/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9194 - loss: 0.2807 - val_accuracy: 0.7685 - val_loss: 1.5702
# Epoch 21/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9275 - loss: 0.2500 - val_accuracy: 0.7763 - val_loss: 1.6275
# Epoch 22/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9251 - loss: 0.2698 - val_accuracy: 0.7735 - val_loss: 1.6881
# Epoch 23/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9248 - loss: 0.2683 - val_accuracy: 0.7685 - val_loss: 1.6807
# Epoch 24/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9246 - loss: 0.2732 - val_accuracy: 0.7696 - val_loss: 1.6438
# Epoch 25/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9161 - loss: 0.2906 - val_accuracy: 0.7713 - val_loss: 1.6297
# Epoch 26/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9237 - loss: 0.2572 - val_accuracy: 0.7685 - val_loss: 1.6165
# Epoch 27/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9188 - loss: 0.2746 - val_accuracy: 0.7590 - val_loss: 1.6431
# Epoch 28/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 9s 10ms/step - accuracy: 0.9271 - loss: 0.2636 - val_accuracy: 0.7741 - val_loss: 1.6685
# Epoch 29/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9262 - loss: 0.2356 - val_accuracy: 0.7652 - val_loss: 1.6999
# Epoch 30/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9224 - loss: 0.2632 - val_accuracy: 0.7696 - val_loss: 1.7091
# Epoch 31/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9241 - loss: 0.2516 - val_accuracy: 0.7685 - val_loss: 1.6798
# Epoch 32/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9132 - loss: 0.3203 - val_accuracy: 0.7696 - val_loss: 1.7965
# Epoch 33/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9296 - loss: 0.2601 - val_accuracy: 0.7830 - val_loss: 1.7804
# Epoch 34/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9331 - loss: 0.2228 - val_accuracy: 0.7696 - val_loss: 1.7351
# Epoch 35/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9316 - loss: 0.2599 - val_accuracy: 0.7730 - val_loss: 1.7970
# Epoch 36/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 8ms/step - accuracy: 0.9326 - loss: 0.2216 - val_accuracy: 0.7713 - val_loss: 1.7594
# Epoch 37/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 8s 9ms/step - accuracy: 0.9265 - loss: 0.2411 - val_accuracy: 0.7702 - val_loss: 1.8730
# Epoch 38/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9294 - loss: 0.2428 - val_accuracy: 0.7646 - val_loss: 1.8566
# Epoch 39/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 11s 10ms/step - accuracy: 0.9293 - loss: 0.2439 - val_accuracy: 0.7652 - val_loss: 1.8311
# Epoch 40/40
# 899/899 ━━━━━━━━━━━━━━━━━━━━ 10s 9ms/step - accuracy: 0.9345 - loss: 0.2247 - val_accuracy: 0.7707 - val_loss: 1.8731

# %%
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import LSTM, Dropout, Dense

rnn_model = Sequential([
    LSTM(128, return_sequences=True, input_shape=(100, 256)),  # 시퀀스 유지
    Dropout(0.3),
    LSTM(64),                             # 추가 RNN 계층 (요약 정보 학습)
    Dense(128, activation='relu'),        # 중간 표현 확대
    Dropout(0.4),                         # 과적합 방지 강화
    Dense(46, activation='softmax')       # 다중 분류
])

rnn_model.compile(
    optimizer='adam',
    loss='sparse_categorical_crossentropy',
    metrics=['accuracy']
)
# Out:
# /usr/local/lib/python3.11/dist-packages/keras/src/layers/rnn/rnn.py:200: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)

# %%
# 시간이 좀 걸립니다! 한 20분정도
rnn_model.fit(x_train_w2v, y_train, epochs=40, batch_size=16, validation_split=0.2)
# Out:
# Epoch 1/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 7s 16ms/step - accuracy: 0.9452 - loss: 0.2012 - val_accuracy: 0.8036 - val_loss: 1.6351
# Epoch 2/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 15ms/step - accuracy: 0.9507 - loss: 0.1630 - val_accuracy: 0.8002 - val_loss: 1.6881
# Epoch 3/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 9s 12ms/step - accuracy: 0.9551 - loss: 0.1386 - val_accuracy: 0.7947 - val_loss: 1.7061
# Epoch 4/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9492 - loss: 0.1576 - val_accuracy: 0.7941 - val_loss: 1.6524
# Epoch 5/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9457 - loss: 0.1702 - val_accuracy: 0.7908 - val_loss: 1.7504
# Epoch 6/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9452 - loss: 0.1728 - val_accuracy: 0.7919 - val_loss: 1.7477
# Epoch 7/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9485 - loss: 0.1635 - val_accuracy: 0.7991 - val_loss: 1.7093
# Epoch 8/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9494 - loss: 0.1596 - val_accuracy: 0.7986 - val_loss: 1.8381
# Epoch 9/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9508 - loss: 0.1431 - val_accuracy: 0.7880 - val_loss: 1.8264
# Epoch 10/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9546 - loss: 0.1373 - val_accuracy: 0.7746 - val_loss: 1.8517
# Epoch 11/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9539 - loss: 0.1478 - val_accuracy: 0.7924 - val_loss: 1.8916
# Epoch 12/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9525 - loss: 0.1445 - val_accuracy: 0.7913 - val_loss: 1.8057
# Epoch 13/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9572 - loss: 0.1306 - val_accuracy: 0.7974 - val_loss: 1.9026
# Epoch 14/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9568 - loss: 0.1240 - val_accuracy: 0.7969 - val_loss: 1.9327
# Epoch 15/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9587 - loss: 0.1222 - val_accuracy: 0.7874 - val_loss: 1.8802
# Epoch 16/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9503 - loss: 0.1545 - val_accuracy: 0.7908 - val_loss: 1.9881
# Epoch 17/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 13ms/step - accuracy: 0.9512 - loss: 0.1441 - val_accuracy: 0.7885 - val_loss: 2.0665
# Epoch 18/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9610 - loss: 0.1222 - val_accuracy: 0.7919 - val_loss: 2.0064
# Epoch 19/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9541 - loss: 0.1321 - val_accuracy: 0.7952 - val_loss: 1.9915
# Epoch 20/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9592 - loss: 0.1187 - val_accuracy: 0.7835 - val_loss: 1.9553
# Epoch 21/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9546 - loss: 0.1371 - val_accuracy: 0.7874 - val_loss: 2.1136
# Epoch 22/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9577 - loss: 0.1221 - val_accuracy: 0.7919 - val_loss: 2.0617
# Epoch 23/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9578 - loss: 0.1280 - val_accuracy: 0.7930 - val_loss: 2.0675
# Epoch 24/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 13ms/step - accuracy: 0.9544 - loss: 0.1320 - val_accuracy: 0.7880 - val_loss: 2.1542
# Epoch 25/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9584 - loss: 0.1212 - val_accuracy: 0.7813 - val_loss: 2.0744
# Epoch 26/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9588 - loss: 0.1174 - val_accuracy: 0.7852 - val_loss: 2.1609
# Epoch 27/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9545 - loss: 0.1239 - val_accuracy: 0.7819 - val_loss: 2.1693
# Epoch 28/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9612 - loss: 0.1114 - val_accuracy: 0.7852 - val_loss: 2.1011
# Epoch 29/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 12ms/step - accuracy: 0.9580 - loss: 0.1181 - val_accuracy: 0.7841 - val_loss: 2.0743
# Epoch 30/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9612 - loss: 0.1107 - val_accuracy: 0.7913 - val_loss: 2.2047
# Epoch 31/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9558 - loss: 0.1241 - val_accuracy: 0.7858 - val_loss: 2.1544
# Epoch 32/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 10s 14ms/step - accuracy: 0.9555 - loss: 0.1277 - val_accuracy: 0.7913 - val_loss: 2.3206
# Epoch 33/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9571 - loss: 0.1214 - val_accuracy: 0.7874 - val_loss: 2.1687
# Epoch 34/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 11s 13ms/step - accuracy: 0.9605 - loss: 0.1152 - val_accuracy: 0.7891 - val_loss: 2.2383
# Epoch 35/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 11s 14ms/step - accuracy: 0.9583 - loss: 0.1155 - val_accuracy: 0.7874 - val_loss: 2.3203
# Epoch 36/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9588 - loss: 0.1131 - val_accuracy: 0.7785 - val_loss: 2.1465
# Epoch 37/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9524 - loss: 0.1164 - val_accuracy: 0.7830 - val_loss: 2.3101
# Epoch 38/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 5s 12ms/step - accuracy: 0.9590 - loss: 0.1018 - val_accuracy: 0.7880 - val_loss: 2.2039
# Epoch 39/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 14ms/step - accuracy: 0.9603 - loss: 0.1048 - val_accuracy: 0.7902 - val_loss: 2.2132
# Epoch 40/40
# 450/450 ━━━━━━━━━━━━━━━━━━━━ 6s 12ms/step - accuracy: 0.9571 - loss: 0.1166 - val_accuracy: 0.7930 - val_loss: 2.3816

# %% [markdown]
# # 로스가 떨어지는 폭을 보아하니 좀더 돌리면 점수가 더 높게 나올것같습니다!
#
# 여기까지 실험하고 시간이 좀 남으시는 분들만 실험해보시길

# %%
y_pred_proba = rnn_model.predict(x_test_w2v)
y_pred = np.argmax(y_pred_proba, axis=1)

acc = accuracy_score(y_test, y_pred)
f1 = f1_score(y_test, y_pred, average='weighted')

print(f"✅ Accuracy: {acc:.4f}")
print(f"✅ F1-score: {f1:.4f}")
# Out:
# 71/71 ━━━━━━━━━━━━━━━━━━━━ 0s 6ms/step
# ✅ Accuracy: 0.7894
# ✅ F1-score: 0.7830
